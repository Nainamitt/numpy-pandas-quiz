# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("customer.csv")

# %%
sales = pd.read_csv("sales.csv")

# %%
support = pd.read_csv("support.csv")

# %%
customers.shape
# Out:
# (8, 5)

# %%
sales.shape
# Out:
# (8, 6)

# %%
support.shape
# Out:
# (8, 4)

# %%
customers.columns
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Region', 'SignupDate'], dtype='object')

# %%
sales.columns
# Out:
# Index(['OrderID', 'CustomerID', 'Product', 'Quantity', 'Price', 'OrderDate'], dtype='object')

# %%
support.columns
# Out:
# Index(['TicketID', 'CustomerID', 'IssueType', 'ResolutionTime'], dtype='object')

# %%
customers.isnull().sum()
# Out:
# CustomerID    0
# Name          0
# Age           1
# Region        0
# SignupDate    0
# dtype: int64

# %%
sales.isnull().sum()
# Out:
# OrderID       0
# CustomerID    0
# Product       0
# Quantity      0
# Price         0
# OrderDate     0
# dtype: int64

# %%
support.isnull().sum()
# Out:
# TicketID          0
# CustomerID        0
# IssueType         0
# ResolutionTime    0
# dtype: int64

# %%
price_array = sales["Price"].values
price_array
# Out:
# array([55000, 25000, 15000, 60000, 22000,  2000, 58000, 18000])

# %%
# Apply 10% discount using broadcasting
discounted_prices = price_array * 0.1
sales["Discounted_Price"] = discounted_prices
discounted_prices
# Out:
# array([5500., 2500., 1500., 6000., 2200.,  200., 5800., 1800.])

# %%
sales["Revenue"] = sales["Quantity"] * sales["Price"]
sales["Revenue"]
# Out:
# 0    110000
# 1     25000
# 2     45000
# 3     60000
# 4     44000
# 5     10000
# 6     58000
# 7     36000
# Name: Revenue, dtype: int64

# %%
sales["OrderDate"] = pd.to_datetime(sales["OrderDate"])
sales["OrderDate"]
sales[sales["OrderDate"].dt.month==1]
# Out:
# 0   2023-04-10
# 1   2023-04-12
# 2   2023-05-01
# 3   2023-05-15
# 4   2023-06-05
# 5   2023-06-10
# 6   2023-07-02
# 7   2023-07-20
# Name: OrderDate, dtype: datetime64[ns]

# %%
sales[0:11]
# Out:
#   OrderID CustomerID     Product  Quantity  Price  OrderDate  \
# 0   O1001       C001      Laptop         2  55000 2023-04-10
# 1   O1002       C002      Mobile         1  25000 2023-04-12
# 2   O1003       C003      Tablet         3  15000 2023-05-01
# 3   O1004       C004      Laptop         1  60000 2023-05-15
# 4   O1005       C005      Mobile         2  22000 2023-06-05
# 5   O1006       C006  Headphones         5   2000 2023-06-10
# 6   O1007       C007      Laptop         1  58000 2023-07-02
# 7   O1008       C008      Tablet         2  18000 2023-07-20
#
#    Discounted_Price  Revenue
# 0            5500.0   110000
# 1            2500.0    25000
# 2            1500.0    45000
# 3            6000.0    60000
# 4            2200.0    44000
# 5             200.0    10000
# 6            5800.0    58000
# 7            1800.0    36000

# %%
customers[customers["Region"] == "North"]
# Out:
#   CustomerID   Name   Age Region  SignupDate
# 0       C001   Amit  28.0  North  2023-01-15
# 4       C005  David  30.0  North  2023-02-10

# %%
sales[sales["Revenue"] > 10000]
# Out:
#   OrderID CustomerID Product  Quantity  Price  OrderDate  Discounted_Price  \
# 0   O1001       C001  Laptop         2  55000 2023-04-10            5500.0
# 1   O1002       C002  Mobile         1  25000 2023-04-12            2500.0
# 2   O1003       C003  Tablet         3  15000 2023-05-01            1500.0
# 3   O1004       C004  Laptop         1  60000 2023-05-15            6000.0
# 4   O1005       C005  Mobile         2  22000 2023-06-05            2200.0
# 6   O1007       C007  Laptop         1  58000 2023-07-02            5800.0
# 7   O1008       C008  Tablet         2  18000 2023-07-20            1800.0
#
#    Revenue
# 0   110000
# 1    25000
# 2    45000
# 3    60000
# 4    44000
# 6    58000
# 7    36000

# %%
customers["SignupDate"] = pd.to_datetime(customers["SignupDate"])
customers.sort_values(by="SignupDate")
# Out:
#   CustomerID   Name   Age Region SignupDate
# 3       C004   Sara  42.0   West 2021-07-12
# 5       C006  Meera  27.0  South 2022-09-18
# 1       C002  Priya  35.0  South 2022-11-20
# 7       C008   Ravi  40.0   West 2022-12-01
# 0       C001   Amit  28.0  North 2023-01-15
# 6       C007   Alex  33.0   East 2023-01-25
# 4       C005  David  30.0  North 2023-02-10
# 2       C003   John   NaN   East 2023-03-05

# %%
sales.sort_values("Revenue" , ascending = False)
# Out:
#   OrderID CustomerID     Product  Quantity  Price  OrderDate  \
# 0   O1001       C001      Laptop         2  55000 2023-04-10
# 3   O1004       C004      Laptop         1  60000 2023-05-15
# 6   O1007       C007      Laptop         1  58000 2023-07-02
# 2   O1003       C003      Tablet         3  15000 2023-05-01
# 4   O1005       C005      Mobile         2  22000 2023-06-05
# 7   O1008       C008      Tablet         2  18000 2023-07-20
# 1   O1002       C002      Mobile         1  25000 2023-04-12
# 5   O1006       C006  Headphones         5   2000 2023-06-10
#
#    Discounted_Price  Revenue
# 0            5500.0   110000
# 3            6000.0    60000
# 6            5800.0    58000
# 2            1500.0    45000
# 4            2200.0    44000
# 7            1800.0    36000
# 1            2500.0    25000
# 5             200.0    10000

# %%
sales_with_region = sales.merge(customers, on="CustomerID", how="left")
sales_with_region.groupby("Region")["Revenue"].mean()
# Out:
# Region
# East     51500.0
# North    77000.0
# South    17500.0
# West     48000.0
# Name: Revenue, dtype: float64

# %%
support.groupby("IssueType")["ResolutionTime"].mean()
# Out:
# IssueType
# Delivery Delay    38.000000
# Payment Issue     18.666667
# Product Defect    66.000000
# Name: ResolutionTime, dtype: float64

# %%
customers["Age"].fillna(customers["Age"].median())
# Out:
# 0    28.0
# 1    35.0
# 2    33.0
# 3    42.0
# 4    30.0
# 5    27.0
# 6    33.0
# 7    40.0
# Name: Age, dtype: float64

# %%
customers.rename(columns={"CustomerID": "CustomerID"}, inplace=True)
sales.rename(columns={"CustomerID": "CustomerID"}, inplace=True)
support.rename(columns={"CustomerID": "CustomerID"}, inplace=True)

# %%
merged_df = sales.merge(customers, on="CustomerID", how="left")
merged_df = merged_df.merge(support, on="CustomerID", how="left")
merged_df.shape
# Out:
# (8, 15)

# %%
clv = merged_df.groupby("CustomerID")["Revenue"].sum().reset_index()
clv.rename(columns={"Revenue": "CLV"}, inplace=True)

merged_df = merged_df.merge(clv, on="CustomerID", how="left")

# %%
avg_resolution_customer = merged_df.groupby("CustomerID")["ResolutionTime"].mean().reset_index()
avg_resolution_customer.rename(columns={"ResolutionTime": "Avg_Resolution_Time"}, inplace=True)

merged_df = merged_df.merge(avg_resolution_customer, on="CustomerID", how="left")

# %%
merged_df.to_csv("Cleaned_Data.csv", index=False)
print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!
